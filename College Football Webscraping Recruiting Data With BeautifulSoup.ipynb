# %%
from bs4 import BeautifulSoup
import urllib.request
from IPython.display import HTML
import re
import pandas as pd
import numpy as np

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
req = urllib.request.Request(url = 'https://247sports.com/season/2020-football/compositeteamrankings/', headers = headers)
r = urllib.request.urlopen(req).read()
soup = BeautifulSoup(r)

#headers = {‘User-Agent’: ‘Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3’}
#reg_url = “https:XXXXOOOO"
#req = Request(url=reg_url, headers=headers) 
#html = urlopen(req).read()

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="twofourseven-site" data-template="responsive" lang="en-US" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="247Sports" name="application-name"/>
#   <meta content="#005695" name="msapplication-TileColor"/>
#   <meta content="https://assets.247sports.com/Content/Img/logo_win8.png" name="msapplication-TileImage"/>
#   <title>
#    2020 Football Team Rankings
#   </title>
#   <link href="https://assets.247sports.com/Content/Img/247touch.png" rel="apple-touch-icon"/>
#   <link href="https://assets.247sports.com/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="https://assets.247sports.com/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="1523983947844395" property="fb:app_id"/>
# ...

# %%
tag = soup.find_all("li", class_ ='rankings-page__list-item')
# //*[@id="page-content"]/div/section/section/div/ul/li[2]/div[1]
print(soup.find_all("div", class_ = 'avg'))
# Out:
# [<div class="avg"> 92.96 </div>, <div class="avg"> 93.56 </div>, <div class="avg"> 93.45 </div>, <div class="avg"> 92.84 </div>, <div class="avg"> 91.80 </div>, <div class="avg"> 91.13 </div>, <div class="avg"> 90.89 </div>, <div class="avg"> 90.70 </div>, <div class="avg"> 91.90 </div>, <div class="avg"> 89.92 </div>, <div class="avg"> 90.40 </div>, <div class="avg"> 90.19 </div>, <div class="avg"> 89.97 </div>, <div class="avg"> 90.35 </div>, <div class="avg"> 89.55 </div>, <div class="avg"> 88.76 </div>, <div class="avg"> 90.75 </div>, <div class="avg"> 88.63 </div>, <div class="avg"> 88.49 </div>, <div class="avg"> 88.38 </div>, <div class="avg"> 87.17 </div>, <div class="avg"> 87.97 </div>, <div class="avg"> 88.39 </div>, <div class="avg"> 88.12 </div>, <div class="avg"> 87.82 </div>, <div class="avg"> 87.21 </div>, <div class="avg"> 87.51 </div>, <div class="avg"> 87.89 </div>, <div class="avg"> 86.53 </div>, <div class="avg"> 86.75 </div>, <div class="avg"> 85.62 </div>, <div 
# ...

# %%
newtag = soup.find_all("div", class_ = 'primary')
thing = str(newtag[0])
thing[21:].index('>')
empt = []
for item in soup.find_all("div", class_ = 'primary'):
    thing = str(item)
    start = thing.index('">')
    end = thing.index('</')
    place = thing[start+2:end]
    place = place.strip()
    empt.append(place)
    
empt2 = []
for item in soup.find_all("div", class_ = 'team'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt2.append(place)
empt2

empt3 = []
for item in soup.find_all("div", class_ = 'total'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt3.append(place)
empt3

empt4 = []
for item in soup.find_all("div", class_ = 'avg'):
    thing = str(item)
    start = thing.index('g">')
    end = thing.index('</div>')
    place = thing[start+4:end]
    place = place.strip()
    empt4.append(place)
empt4

empt5 = []
for item in soup.find_all("div", class_ = 'points'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt5.append(place)
empt5

d = {'Rank': empt, 'School': empt2, 'Number of Commits':empt3, 'Average Recruit Ranking':empt4, 'Total Recruit Points':empt5}
df = pd.DataFrame(data=d)
df.head()
# Out:
#   Rank      School Number of Commits Average Recruit Ranking  \
# 0    1     Georgia        25 Commits                   92.96
# 1    2     Alabama        25 Commits                   93.56
# 2    3     Clemson        23 Commits                   93.45
# 3    4         LSU        24 Commits                   92.84
# 4    5  Ohio State        25 Commits                   91.80
#
#   Total Recruit Points
# 0               313.34
# 1               310.44
# 2               309.73
# 3               300.54
# 4               295.08

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
req = urllib.request.Request(url = 'https://247sports.com/Season/2020-Football/CompositeTeamRankings/?Conference=Big-12', headers = headers)
r = urllib.request.urlopen(req).read()
soup = BeautifulSoup(r)

empt = []
for item in soup.find_all("div", class_ = 'primary'):
    thing = str(item)
    start = thing.index('">')
    end = thing.index('</')
    place = thing[start+2:end]
    place = place.strip()
    empt.append(place)
    
empt2 = []
for item in soup.find_all("div", class_ = 'team'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt2.append(place)
empt2

empt3 = []
for item in soup.find_all("div", class_ = 'total'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt3.append(place)
empt3

empt4 = []
for item in soup.find_all("div", class_ = 'avg'):
    thing = str(item)
    start = thing.index('g">')
    end = thing.index('</div>')
    place = thing[start+4:end]
    place = place.strip()
    empt4.append(place)
empt4

empt5 = []
for item in soup.find_all("div", class_ = 'points'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt5.append(place)
empt5

d = {'Rank': empt, 'School': empt2, 'Number of Commits':empt3, 'Average Recruit Ranking':empt4, 'Total Recruit Points':empt5}
BigTwelve2020df = pd.DataFrame(data=d)
BigTwelve2020df.to_csv('BigTwelve2020.csv')
BigTwelve2020df.head()
# Out:
#   Rank          School Number of Commits Average Recruit Ranking  \
# 0    1           Texas        19 Commits                   91.90
# 1    2        Oklahoma        23 Commits                   90.40
# 2    3             TCU        18 Commits                   87.89
# 3    4   West Virginia        22 Commits                   86.44
# 4    5  Oklahoma State        21 Commits                   85.57
#
#   Total Recruit Points
# 0               270.93
# 1               259.60
# 2               215.88
# 3               199.77
# 4               192.35

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
req = urllib.request.Request(url = 'https://247sports.com/Season/2019-Football/CompositeTeamRankings/?Conference=Big-12', headers = headers)
r = urllib.request.urlopen(req).read()
soup = BeautifulSoup(r)

empt = []
for item in soup.find_all("div", class_ = 'primary'):
    thing = str(item)
    start = thing.index('">')
    end = thing.index('</')
    place = thing[start+2:end]
    place = place.strip()
    empt.append(place)
    
empt2 = []
for item in soup.find_all("div", class_ = 'team'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt2.append(place)
empt2

empt3 = []
for item in soup.find_all("div", class_ = 'total'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt3.append(place)
empt3

empt4 = []
for item in soup.find_all("div", class_ = 'avg'):
    thing = str(item)
    start = thing.index('g">')
    end = thing.index('</div>')
    place = thing[start+4:end]
    place = place.strip()
    empt4.append(place)
empt4

empt5 = []
for item in soup.find_all("div", class_ = 'points'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt5.append(place)
empt5

d = {'Rank': empt, 'School': empt2, 'Number of Commits':empt3, 'Average Recruit Ranking':empt4, 'Total Recruit Points':empt5}
BigTwelve2019df = pd.DataFrame(data=d)
BigTwelve2019df.to_csv('BigTwelve2019.csv')
BigTwelve2019df.head()
# Out:
#   Rank          School Number of Commits Average Recruit Ranking  \
# 0    1           Texas        26 Commits                   91.19
# 1    2        Oklahoma        24 Commits                   91.20
# 2    3             TCU        27 Commits                   86.53
# 3    4          Baylor        24 Commits                   85.95
# 4    5  Oklahoma State        21 Commits                   86.01
#
#   Total Recruit Points
# 0               287.69
# 1               279.28
# 2               217.48
# 3               202.87
# 4               202.09

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
req = urllib.request.Request(url = 'https://247sports.com/Season/2018-Football/CompositeTeamRankings/?Conference=Big-12', headers = headers)
r = urllib.request.urlopen(req).read()
soup = BeautifulSoup(r)

empt = []
for item in soup.find_all("div", class_ = 'primary'):
    thing = str(item)
    start = thing.index('">')
    end = thing.index('</')
    place = thing[start+2:end]
    place = place.strip()
    empt.append(place)
    
empt2 = []
for item in soup.find_all("div", class_ = 'team'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt2.append(place)
empt2

empt3 = []
for item in soup.find_all("div", class_ = 'total'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt3.append(place)
empt3

empt4 = []
for item in soup.find_all("div", class_ = 'avg'):
    thing = str(item)
    start = thing.index('g">')
    end = thing.index('</div>')
    place = thing[start+4:end]
    place = place.strip()
    empt4.append(place)
empt4

empt5 = []
for item in soup.find_all("div", class_ = 'points'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt5.append(place)
empt5

d = {'Rank': empt, 'School': empt2, 'Number of Commits':empt3, 'Average Recruit Ranking':empt4, 'Total Recruit Points':empt5}
BigTwelve2018df = pd.DataFrame(data=d)
BigTwelve2018df.to_csv('BigTwelve2018.csv')
BigTwelve2018df.head()
# Out:
#   Rank          School Number of Commits Average Recruit Ranking  \
# 0    1           Texas        27 Commits                   92.16
# 1    2        Oklahoma        23 Commits                   90.95
# 2    3             TCU        25 Commits                   87.13
# 3    4          Baylor        23 Commits                   86.77
# 4    5  Oklahoma State        24 Commits                   86.52
#
#   Total Recruit Points
# 0               300.06
# 1               276.62
# 2               224.13
# 3               215.02
# 4               209.93

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
req = urllib.request.Request(url = 'https://247sports.com/Season/2017-Football/CompositeTeamRankings/?Conference=Big-12', headers = headers)
r = urllib.request.urlopen(req).read()
soup = BeautifulSoup(r)

empt = []
for item in soup.find_all("div", class_ = 'primary'):
    thing = str(item)
    start = thing.index('">')
    end = thing.index('</')
    place = thing[start+2:end]
    place = place.strip()
    empt.append(place)
    
empt2 = []
for item in soup.find_all("div", class_ = 'team'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt2.append(place)
empt2

empt3 = []
for item in soup.find_all("div", class_ = 'total'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt3.append(place)
empt3

empt4 = []
for item in soup.find_all("div", class_ = 'avg'):
    thing = str(item)
    start = thing.index('g">')
    end = thing.index('</div>')
    place = thing[start+4:end]
    place = place.strip()
    empt4.append(place)
empt4

empt5 = []
for item in soup.find_all("div", class_ = 'points'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt5.append(place)
empt5

d = {'Rank': empt, 'School': empt2, 'Number of Commits':empt3, 'Average Recruit Ranking':empt4, 'Total Recruit Points':empt5}
BigTwelve2017df = pd.DataFrame(data=d)
BigTwelve2017df.to_csv('BigTwelve2017.csv')
BigTwelve2017df.head()
# Out:
#   Rank          School Number of Commits Average Recruit Ranking  \
# 0    1        Oklahoma        28 Commits                   89.93
# 1    2           Texas        18 Commits                   87.58
# 2    3             TCU        23 Commits                   85.18
# 3    4  Oklahoma State        22 Commits                   84.95
# 4    5          Baylor        28 Commits                   84.60
#
#   Total Recruit Points
# 0               270.79
# 1               217.76
# 2               210.03
# 3               194.18
# 4               193.36

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
req = urllib.request.Request(url = 'https://247sports.com/Season/2016-Football/CompositeTeamRankings/?Conference=Big-12', headers = headers)
r = urllib.request.urlopen(req).read()
soup = BeautifulSoup(r)

empt = []
for item in soup.find_all("div", class_ = 'primary'):
    thing = str(item)
    start = thing.index('">')
    end = thing.index('</')
    place = thing[start+2:end]
    place = place.strip()
    empt.append(place)
    
empt2 = []
for item in soup.find_all("div", class_ = 'team'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt2.append(place)
empt2

empt3 = []
for item in soup.find_all("div", class_ = 'total'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt3.append(place)
empt3

empt4 = []
for item in soup.find_all("div", class_ = 'avg'):
    thing = str(item)
    start = thing.index('g">')
    end = thing.index('</div>')
    place = thing[start+4:end]
    place = place.strip()
    empt4.append(place)
empt4

empt5 = []
for item in soup.find_all("div", class_ = 'points'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt5.append(place)
empt5

d = {'Rank': empt, 'School': empt2, 'Number of Commits':empt3, 'Average Recruit Ranking':empt4, 'Total Recruit Points':empt5}
BigTwelve2016df = pd.DataFrame(data=d)
BigTwelve2016df.to_csv('BigTwelve2016.csv')
BigTwelve2016df.head()
# Out:
#   Rank         School Number of Commits Average Recruit Ranking  \
# 0    1          Texas        29 Commits                   90.07
# 1    2       Oklahoma        21 Commits                   88.49
# 2    3            TCU        23 Commits                   88.25
# 3    4  West Virginia        28 Commits                   83.08
# 4    5         Baylor        17 Commits                   86.03
#
#   Total Recruit Points
# 0               280.66
# 1               238.73
# 2               235.79
# 3               194.45
# 4               191.99

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
req = urllib.request.Request(url = 'https://247sports.com/Season/2015-Football/CompositeTeamRankings/?Conference=Big-12', headers = headers)
r = urllib.request.urlopen(req).read()
soup = BeautifulSoup(r)

empt = []
for item in soup.find_all("div", class_ = 'primary'):
    thing = str(item)
    start = thing.index('">')
    end = thing.index('</')
    place = thing[start+2:end]
    place = place.strip()
    empt.append(place)
    
empt2 = []
for item in soup.find_all("div", class_ = 'team'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt2.append(place)
empt2

empt3 = []
for item in soup.find_all("div", class_ = 'total'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt3.append(place)
empt3

empt4 = []
for item in soup.find_all("div", class_ = 'avg'):
    thing = str(item)
    start = thing.index('g">')
    end = thing.index('</div>')
    place = thing[start+4:end]
    place = place.strip()
    empt4.append(place)
empt4

empt5 = []
for item in soup.find_all("div", class_ = 'points'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt5.append(place)
empt5

d = {'Rank': empt, 'School': empt2, 'Number of Commits':empt3, 'Average Recruit Ranking':empt4, 'Total Recruit Points':empt5}
BigTwelve2015df = pd.DataFrame(data=d)
BigTwelve2015df.to_csv('BigTwelve2015.csv')
BigTwelve2015df.head()
# Out:
#   Rank         School Number of Commits Average Recruit Ranking  \
# 0    1          Texas        29 Commits                   89.43
# 1    2       Oklahoma        28 Commits                   88.20
# 2    3     Texas Tech        19 Commits                   85.79
# 3    4  West Virginia        22 Commits                   84.75
# 4    5         Baylor        19 Commits                   85.20
#
#   Total Recruit Points
# 0               272.49
# 1               249.69
# 2               203.18
# 3               198.02
# 4               195.88

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
req = urllib.request.Request(url = 'https://247sports.com/Season/2014-Football/CompositeTeamRankings/?Conference=Big-12', headers = headers)
r = urllib.request.urlopen(req).read()
soup = BeautifulSoup(r)

empt = []
for item in soup.find_all("div", class_ = 'primary'):
    thing = str(item)
    start = thing.index('">')
    end = thing.index('</')
    place = thing[start+2:end]
    place = place.strip()
    empt.append(place)
    
empt2 = []
for item in soup.find_all("div", class_ = 'team'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt2.append(place)
empt2

empt3 = []
for item in soup.find_all("div", class_ = 'total'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt3.append(place)
empt3

empt4 = []
for item in soup.find_all("div", class_ = 'avg'):
    thing = str(item)
    start = thing.index('g">')
    end = thing.index('</div>')
    place = thing[start+4:end]
    place = place.strip()
    empt4.append(place)
empt4

empt5 = []
for item in soup.find_all("div", class_ = 'points'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt5.append(place)
empt5

d = {'Rank': empt, 'School': empt2, 'Number of Commits':empt3, 'Average Recruit Ranking':empt4, 'Total Recruit Points':empt5}
BigTwelve2014df = pd.DataFrame(data=d)
BigTwelve2014df.to_csv('BigTwelve2014.csv')
BigTwelve2014df.head()
# Out:
#   Rank          School Number of Commits Average Recruit Ranking  \
# 0    1        Oklahoma        28 Commits                   87.30
# 1    2           Texas        23 Commits                   88.09
# 2    3          Baylor        28 Commits                   85.39
# 3    4  Oklahoma State        27 Commits                   85.91
# 4    5   West Virginia        23 Commits                   84.12
#
#   Total Recruit Points
# 0               248.94
# 1               239.85
# 2               218.13
# 3               217.59
# 4               194.85

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
req = urllib.request.Request(url = 'https://247sports.com/Season/2013-Football/CompositeTeamRankings/?Conference=Big-12', headers = headers)
r = urllib.request.urlopen(req).read()
soup = BeautifulSoup(r)

empt = []
for item in soup.find_all("div", class_ = 'primary'):
    thing = str(item)
    start = thing.index('">')
    end = thing.index('</')
    place = thing[start+2:end]
    place = place.strip()
    empt.append(place)
    
empt2 = []
for item in soup.find_all("div", class_ = 'team'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt2.append(place)
empt2

empt3 = []
for item in soup.find_all("div", class_ = 'total'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt3.append(place)
empt3

empt4 = []
for item in soup.find_all("div", class_ = 'avg'):
    thing = str(item)
    start = thing.index('g">')
    end = thing.index('</div>')
    place = thing[start+4:end]
    place = place.strip()
    empt4.append(place)
empt4

empt5 = []
for item in soup.find_all("div", class_ = 'points'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt5.append(place)
empt5

d = {'Rank': empt, 'School': empt2, 'Number of Commits':empt3, 'Average Recruit Ranking':empt4, 'Total Recruit Points':empt5}
BigTwelve2013df = pd.DataFrame(data=d)
BigTwelve2013df.to_csv('BigTwelve2013.csv')
BigTwelve2013df.head()
# Out:
#   Rank          School Number of Commits Average Recruit Ranking  \
# 0    1        Oklahoma        24 Commits                   87.74
# 1    2           Texas        15 Commits                   90.76
# 2    3          Baylor        25 Commits                   84.68
# 3    4   West Virginia        28 Commits                   84.87
# 4    5  Oklahoma State        25 Commits                   84.56
#
#   Total Recruit Points
# 0               241.93
# 1               234.52
# 2               209.23
# 3               201.03
# 4               199.52

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
req = urllib.request.Request(url = 'https://247sports.com/Season/2012-Football/CompositeTeamRankings/?Conference=Big-12', headers = headers)
r = urllib.request.urlopen(req).read()
soup = BeautifulSoup(r)

empt = []
for item in soup.find_all("div", class_ = 'primary'):
    thing = str(item)
    start = thing.index('">')
    end = thing.index('</')
    place = thing[start+2:end]
    place = place.strip()
    empt.append(place)
    
empt2 = []
for item in soup.find_all("div", class_ = 'team'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt2.append(place)
empt2

empt3 = []
for item in soup.find_all("div", class_ = 'total'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt3.append(place)
empt3

empt4 = []
for item in soup.find_all("div", class_ = 'avg'):
    thing = str(item)
    start = thing.index('g">')
    end = thing.index('</div>')
    place = thing[start+4:end]
    place = place.strip()
    empt4.append(place)
empt4

empt5 = []
for item in soup.find_all("div", class_ = 'points'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt5.append(place)
empt5

d = {'Rank': empt, 'School': empt2, 'Number of Commits':empt3, 'Average Recruit Ranking':empt4, 'Total Recruit Points':empt5}
BigTwelve2012df = pd.DataFrame(data=d)
BigTwelve2012df.to_csv('BigTwelve2012.csv')
BigTwelve2012df.head()
# Out:
#   Rank      School Number of Commits Average Recruit Ranking  \
# 0    1       Texas        28 Commits                   92.15
# 1    2    Oklahoma        23 Commits                   89.69
# 2    3      Baylor        25 Commits                   85.48
# 3    4  Texas Tech        24 Commits                   85.40
# 4    5         TCU        24 Commits                   86.19
#
#   Total Recruit Points
# 0               300.12
# 1               255.08
# 2               222.62
# 3               220.70
# 4               219.37

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
req = urllib.request.Request(url = 'https://247sports.com/Season/2011-Football/CompositeTeamRankings/?Conference=Big-12', headers = headers)
r = urllib.request.urlopen(req).read()
soup = BeautifulSoup(r)

empt = []
for item in soup.find_all("div", class_ = 'primary'):
    thing = str(item)
    start = thing.index('">')
    end = thing.index('</')
    place = thing[start+2:end]
    place = place.strip()
    empt.append(place)
    
empt2 = []
for item in soup.find_all("div", class_ = 'team'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt2.append(place)
empt2

empt3 = []
for item in soup.find_all("div", class_ = 'total'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt3.append(place)
empt3

empt4 = []
for item in soup.find_all("div", class_ = 'avg'):
    thing = str(item)
    start = thing.index('g">')
    end = thing.index('</div>')
    place = thing[start+4:end]
    place = place.strip()
    empt4.append(place)
empt4

empt5 = []
for item in soup.find_all("div", class_ = 'points'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt5.append(place)
empt5

d = {'Rank': empt, 'School': empt2, 'Number of Commits':empt3, 'Average Recruit Ranking':empt4, 'Total Recruit Points':empt5}
BigTwelve2011df = pd.DataFrame(data=d)
BigTwelve2011df.to_csv('BigTwelve2011.csv')
BigTwelve2011df.head()
# Out:
#   Rank          School Number of Commits Average Recruit Ranking  \
# 0    1           Texas        22 Commits                   91.42
# 1    2        Oklahoma        18 Commits                   90.91
# 2    3      Texas Tech        28 Commits                   86.46
# 3    4  Oklahoma State        25 Commits                   85.64
# 4    5             TCU        26 Commits                   85.78
#
#   Total Recruit Points
# 0               284.05
# 1               256.79
# 2               230.54
# 3               212.82
# 4               207.48

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
req = urllib.request.Request(url = 'https://247sports.com/Season/2010-Football/CompositeTeamRankings/?Conference=Big-12', headers = headers)
r = urllib.request.urlopen(req).read()
soup = BeautifulSoup(r)

empt = []
for item in soup.find_all("div", class_ = 'primary'):
    thing = str(item)
    start = thing.index('">')
    end = thing.index('</')
    place = thing[start+2:end]
    place = place.strip()
    empt.append(place)
    
empt2 = []
for item in soup.find_all("div", class_ = 'team'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt2.append(place)
empt2

empt3 = []
for item in soup.find_all("div", class_ = 'total'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt3.append(place)
empt3

empt4 = []
for item in soup.find_all("div", class_ = 'avg'):
    thing = str(item)
    start = thing.index('g">')
    end = thing.index('</div>')
    place = thing[start+4:end]
    place = place.strip()
    empt4.append(place)
empt4

empt5 = []
for item in soup.find_all("div", class_ = 'points'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt5.append(place)
empt5

d = {'Rank': empt, 'School': empt2, 'Number of Commits':empt3, 'Average Recruit Ranking':empt4, 'Total Recruit Points':empt5}
BigTwelve2010df = pd.DataFrame(data=d)
BigTwelve2010df.to_csv('BigTwelve2010.csv')
BigTwelve2010df.head()
# Out:
#   Rank          School Number of Commits Average Recruit Ranking  \
# 0    1           Texas        24 Commits                   93.90
# 1    2        Oklahoma        30 Commits                   90.85
# 2    3   Texas A&amp;M        24 Commits                   87.72
# 3    4        Missouri        25 Commits                   87.77
# 4    5  Oklahoma State        27 Commits                   86.28
#
#   Total Recruit Points
# 0               312.07
# 1               283.58
# 2               240.98
# 3               229.00
# 4               213.10

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
req = urllib.request.Request(url = 'https://247sports.com/Season/2009-Football/CompositeTeamRankings/?Conference=Big-12', headers = headers)
r = urllib.request.urlopen(req).read()
soup = BeautifulSoup(r)

empt = []
for item in soup.find_all("div", class_ = 'primary'):
    thing = str(item)
    start = thing.index('">')
    end = thing.index('</')
    place = thing[start+2:end]
    place = place.strip()
    empt.append(place)
    
empt2 = []
for item in soup.find_all("div", class_ = 'team'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt2.append(place)
empt2

empt3 = []
for item in soup.find_all("div", class_ = 'total'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt3.append(place)
empt3

empt4 = []
for item in soup.find_all("div", class_ = 'avg'):
    thing = str(item)
    start = thing.index('g">')
    end = thing.index('</div>')
    place = thing[start+4:end]
    place = place.strip()
    empt4.append(place)
empt4

empt5 = []
for item in soup.find_all("div", class_ = 'points'):
    thing = str(item)
    start = thing.index('s/">')
    end = thing.index('</a>')
    place = thing[start+4:end]
    place = place.strip()
    empt5.append(place)
empt5

d = {'Rank': empt, 'School': empt2, 'Number of Commits':empt3, 'Average Recruit Ranking':empt4, 'Total Recruit Points':empt5}
BigTwelve2009df = pd.DataFrame(data=d)
BigTwelve2009df.to_csv('BigTwelve2009.csv')
BigTwelve2009df.head()
# Out:
#   Rank          School Number of Commits Average Recruit Ranking  \
# 0    1           Texas        20 Commits                   92.13
# 1    2        Oklahoma        22 Commits                   89.60
# 2    3   West Virginia        26 Commits                   86.43
# 3    4   Texas A&amp;M        28 Commits                   86.53
# 4    5  Oklahoma State        24 Commits                   85.33
#
#   Total Recruit Points
# 0               277.12
# 1               262.78
# 2               225.23
# 3               219.98
# 4               209.57
